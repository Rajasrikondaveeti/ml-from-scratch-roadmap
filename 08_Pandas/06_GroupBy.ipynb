# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Daksh_Gururkul_IITG_May_2025/08_Pandas/mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['origin'].value_counts()
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
df[df['origin'] == 2]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# 22   25.0          4         104.0         95    2375          17.5
# 23   26.0          4         121.0        113    2234          12.5
# ..    ...        ...           ...        ...     ...           ...
# 354  34.5          4         100.0          ?    2320          15.8
# 359  28.1          4         141.0         80    3230          20.4
# 360  30.7          6         145.0         76    3160          19.6
# 375  36.0          4         105.0         74    1980          15.3
# 394  44.0          4          97.0         52    2130          24.6
#
#      model_year  origin                          name
# 19           70       2  volkswagen 1131 deluxe sedan
# ...

# %%
#pd.to_numeric(df['horsepower'])

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model_year  origin                  name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
df1 = df[df['horsepower'] != '?']
df1 = df1[df1['cylinders'] == 4]
replaced_hp = np.round(pd.to_numeric(df1['horsepower']).mean(),2)
replaced_hp
# Out:
# np.float64(78.28)

# %%
df['horsepower'] = df['horsepower'].replace('?',replaced_hp)

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df = df.drop('name',axis=1)
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
df.groupby('model_year').mean()
# Out:
#                   mpg  cylinders  displacement  horsepower       weight  \
# model_year
# 70          17.689655   6.758621    281.413793  147.827586  3372.793103
# 71          21.250000   5.571429    209.750000  106.010000  2995.428571
# 72          18.714286   5.821429    218.375000  120.178571  3237.714286
# 73          17.100000   6.375000    256.875000  130.475000  3419.025000
# 74          22.703704   5.259259    171.740741   93.640000  2877.925926
# 75          20.266667   5.600000    205.533333  101.066667  3176.800000
# 76          21.573529   5.647059    197.794118  101.117647  3078.735294
# 77          23.375000   5.464286    191.392857  105.071429  2997.357143
# 78          24.061111   5.361111    177.805556   99.694444  2861.805556
# 79          25.093103   5.827586    206.689655  101.206897  3055.344828
# 80          33.696552   4.137931    115.827586   77.536552  2436.655172
# 81          30.334483   4.620690    135.310345   80.940690  2522.931034
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %% [markdown]
# # Multiple Columns

# %%
cylwise = df.groupby(['model_year','cylinders']).mean()
cylwise
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.636923  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
df1.index
# Out:
# Index([ 14,  18,  19,  20,  21,  22,  23,  29,  30,  31,
#        ...
#        385, 388, 390, 391, 392, 393, 394, 395, 396, 397],
#       dtype='int64', length=199)

# %%
cylwise.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
cylwise.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
cylwise.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
cylwise.loc[(74,6)]
# Out:
# mpg               17.857143
# displacement     230.428571
# horsepower        98.325714
# weight          3320.000000
# acceleration      16.857143
# origin             1.000000
# Name: (74, 6), dtype: float64

# %%
cylwise.loc[[75,78]]
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 75         4          25.250000    114.833333   84.916667  2489.250000
#            6          17.583333    233.750000   96.750000  3398.333333
#            8          15.666667    330.500000  142.000000  4108.833333
# 78         4          29.576471    112.117647   79.705882  2296.764706
#            5          20.300000    131.000000  103.000000  2830.000000
#            6          19.066667    213.250000  109.833333  3314.166667
#            8          19.050000    300.833333  135.500000  3563.333333
#
#                       acceleration    origin
# model_year cylinders
# 75         4             15.833333  2.166667
#            6             17.708333  1.000000
#            8             13.166667  1.000000
# 78         4             16.282353  2.117647
#            5             15.900000  2.000000
#            6             16.391667  1.166667
# ...

# %%
df.groupby('model_year').agg(
    {
        'mpg' : ['median','mean'],
        'displacement' : ['std','max','var']
    }
)
# Out:
#               mpg            displacement
#            median       mean          std    max           var
# model_year
# 70          16.00  17.689655   124.421380  455.0  15480.679803
# 71          19.00  21.250000   115.102410  400.0  13248.564815
# 72          18.50  18.714286   123.781964  429.0  15321.974537
# 73          16.00  17.100000   121.722085  455.0  14816.266026
# 74          24.00  22.703704    92.601127  350.0   8574.968661
# 75          19.50  20.266667    87.669730  400.0   7685.981609
# 76          21.00  21.573529    94.422256  351.0   8915.562389
# 77          21.75  23.375000   107.813742  400.0  11623.802910
# 78          20.70  24.061111    76.012713  318.0   5777.932540
# 79          23.90  25.093103    96.307581  360.0   9275.150246
# 80          32.70  33.696552    33.744914  225.0   1138.719212
# 81          31.60  30.334483    58.387929  350.0   3409.150246
# 82          32.00  31.709677    39.352037  262.0   1548.582796
