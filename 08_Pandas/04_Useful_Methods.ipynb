# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Daksh_Gururkul_IITG_May_2025/08_Pandas/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Apply Method

# %%
n1 = 410

# %%
'*'*12+str(n1)[-4:]
# Out:
# '************410'

# %%
def mask_cc(n):
  return '*'*12+str(n)[-4:]

# %%
mask_cc(4676137647685994)
# Out:
# '************5994'

# %%
df['masked_cc'] = df['CC Number'].apply(mask_cc)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID         masked_cc
# 0  Christy Cunningham  3560325168603410    Sun2959  ************3410
# 1      Douglas Tucker  4478071379779230    Sun4608  ************9230
# 2      Travis Walters  6011812112971322    Sun4458  ************1322
# 3    Nathaniel Harris  4676137647685994    Sun5260  ************5994
# 4        Tonya Carter  4832732618637221    Sun2251  ************7221

# %%
def cat_customer(amt):
  if amt < 10:
    return '$'
  elif amt >= 10 and amt <= 17:
    return '$$'
  else:
    return '$$$'

# %%
df['cust_category'] = df['total_bill'].apply(cat_customer)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID         masked_cc  \
# 0  Christy Cunningham  3560325168603410    Sun2959  ************3410
# 1      Douglas Tucker  4478071379779230    Sun4608  ************9230
# 2      Travis Walters  6011812112971322    Sun4458  ************1322
# 3    Nathaniel Harris  4676137647685994    Sun5260  ************5994
# 4        Tonya Carter  4832732618637221    Sun2251  ************7221
#
#   cust_category
# 0            $$
# 1            $$
# 2           $$$
# 3           $$$
# 4           $$$

# %% [markdown]
# # apply with lambda

# %%
df['CC Number'].apply(lambda n : '*'*12+str(n)[-4:])
# Out:
# 0      ************3410
# 1      ************9230
# 2      ************1322
# 3      ************5994
# 4      ************7221
#              ...
# 239    ************2842
# 240    ************5404
# 241    ************7196
# 242    ************0950
# 243    ************8139
# Name: CC Number, Length: 244, dtype: object

# %%
df['total_bill'].apply(lambda b : np.round(b*1.05,2))
# Out:
# 0      17.84
# 1      10.86
# 2      22.06
# 3      24.86
# 4      25.82
#        ...
# 239    30.48
# 240    28.54
# 241    23.80
# 242    18.71
# 243    19.72
# Name: total_bill, Length: 244, dtype: float64

# %%
#sort_values

df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
#
# ...

# %%
df.sort_values(['size','tip'])
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1              8.58
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 125       29.80  4.20  Female     No  Thur   Lunch     6              4.97
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 141       34.30  6.70    Male     No  Thur   Lunch     6              5.72
#
# ...

# %% [markdown]
# # Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
#idxmin and idxmax
df['price_per_person'].max()
# Out:
# 20.27

# %%
df['price_per_person'].idxmax()
# Out:
# 184

# %%
df.iloc[184]
# Out:
# total_bill                     40.55
# tip                              3.0
# sex                             Male
# smoker                           Yes
# day                              Sun
# time                          Dinner
# size                               2
# price_per_person               20.27
# Payer Name               Stephen Cox
# CC Number           3547798222044029
# Payment ID                   Sun5140
# masked_cc           ************4029
# cust_category                    $$$
# Name: 184, dtype: object

# %%
df['price_per_person'].min()
# Out:
# 2.88

# %%
df['price_per_person'].idxmin()
# Out:
# 92

# %%
#Value Counts
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID         masked_cc  \
# 0  Christy Cunningham  3560325168603410    Sun2959  ************3410
# 1      Douglas Tucker  4478071379779230    Sun4608  ************9230
#
#   cust_category
# 0            $$
# 1            $$

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
#replace

df['day'].replace(to_replace='Sun',value='Sunday')
# Out:
# 0      Sunday
# 1      Sunday
# 2      Sunday
# 3      Sunday
# 4      Sunday
#         ...
# 239       Sat
# 240       Sat
# 241       Sat
# 242       Sat
# 243      Thur
# Name: day, Length: 244, dtype: object

# %%
#map

my_map = {'Sat':'Saturday',
          'Sun':'Sunday',
          'Thur':'Thursday'}

# %%
df['day'].map(my_map)
# Out:
# 0        Sunday
# 1        Sunday
# 2        Sunday
# 3        Sunday
# 4        Sunday
#          ...
# 239    Saturday
# 240    Saturday
# 241    Saturday
# 242    Saturday
# 243    Thursday
# Name: day, Length: 244, dtype: object

# %%
#unique

df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
#nunique
df['size'].nunique()
# Out:
# 6

# %%
df['cust_category'].nunique()
# Out:
# 3

# %%
df['time'].nunique()
# Out:
# 2

# %% [markdown]
# #Duplicates

# %%
df.duplicated() #first instance of a duplicated row in your df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([[1,2,2],[1,2,2],[1,2,2]],['a','b','c'])
simple_df
# Out:
#    0  1  2
# a  1  2  2
# b  1  2  2
# c  1  2  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b     True
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0  1  2
# a  1  2  2

# %%
simple_df[simple_df.duplicated()]
# Out:
#    0  1  2
# b  1  2  2
# c  1  2  2

# %%
simple_df
# Out:
#    0  1  2
# a  1  2  2
# b  1  2  2
# c  1  2  2

# %%
#between
df[df['total_bill'].between(left=10,right=20,inclusive='both')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df[df['size'].between(left=2,right=4,inclusive='neither')]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00
# 16        10.33   1.67  Female     No   Sun  Dinner     3              3.44
# 17        16.29   3.71    Male     No   Sun  Dinner     3              5.43
# 18        16.97   3.50  Female     No   Sun  Dinner     3              5.66
# 19        20.65   3.35    Male     No   Sat  Dinner     3              6.88
# 35        24.06   3.60    Male     No   Sat  Dinner     3              8.02
# 36        16.31   2.00    Male     No   Sat  Dinner     3              5.44
# 37        16.93   3.07  Female     No   Sat  Dinner     3              5.64
# 38        18.69   2.31    Male     No   Sat  Dinner     3              6.23
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# ...

# %%
#nlargest
df.nlargest(10,'tip')[['Payer Name','masked_cc']]
# Out:
#             Payer Name         masked_cc
# 170      Gregory Clark  ************8236
# 212    Alex Williamson  ************5212
# 23      Lance Peterson  ************9808
# 59         Brian Ortiz  ************0595
# 141     Steven Carlson  ************8508
# 183  Dr. Michael James  ************9162
# 214    Marissa Jackson  ************1962
# 47        James Barnes  ************4186
# 239      Michael Avila  ************2842
# 88        Roger Taylor  ************9955

# %%
df.nlargest(3,['size','tip'])
# Out:
#      total_bill  tip     sex smoker   day    time  size  price_per_person  \
# 141       34.30  6.7    Male     No  Thur   Lunch     6              5.72
# 143       27.05  5.0  Female     No  Thur   Lunch     6              4.51
# 156       48.17  5.0    Male     No   Sun  Dinner     6              8.03
#
#          Payer Name         CC Number Payment ID         masked_cc  \
# 141  Steven Carlson  3526515703718508   Thur1025  ************8508
# 143    Regina Jones     4311048695487   Thur6179  ************5487
# 156   Ryan Gonzales  3523151482063321    Sun7518  ************3321
#
#     cust_category
# 141           $$$
# 143           $$$
# 156           $$$

# %%
df.nlargest(5,'tip')
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID         masked_cc  \
# 170    Gregory Clark  5473850968388236    Sat1954  ************8236
# 212  Alex Williamson      676218815212    Sat4590  ************5212
# 23    Lance Peterson  3542584061609808     Sat239  ************9808
# 59       Brian Ortiz  6596453823950595    Sat8139  ************0595
# 141   Steven Carlson  3526515703718508   Thur1025  ************8508
#
#     cust_category
# 170           $$$
# 212           $$$
# 23            $$$
# 59            $$$
# ...

# %%
#nsmallest
df.nsmallest(5,'tip')
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No  Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#              Payer Name         CC Number Payment ID         masked_cc  \
# 67        Tiffany Brock  4359488526995267    Sat3455  ************5267
# 92         Leah Ramirez  3508911676966392    Fri3780  ************6392
# 111         Terri Jones  3559221007826887    Sat4801  ************6887
# 236       Matthew Myers  3543676378973965    Sat5032  ************3965
# 0    Christy Cunningham  3560325168603410    Sun2959  ************3410
#
#     cust_category
# 67              $
# 92              $
# 111             $
# ...
