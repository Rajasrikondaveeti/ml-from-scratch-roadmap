# %%
6 > 7
# Out:
# False

# %%
if 6>7:
  print('Hello. This is working because the if condition is True')

# %%
if len('Shreyas')> len('Masai'):
  print('Hello world')
# Out:
# Hello world

# %%
len('Shreyas')> len('Masai')
# Out:
# True

# %%
if 16>7:
  print('Hello. This is working because the if condition is True')
else:
  print('This is getting printed because if condition was not True')
# Out:
# Hello. This is working because the if condition is True

# %% [markdown]
# ### Multiple Branches

# %%
# Out:
# Enter your location here: Delhi

# %%
location
# Out:
# 'Delhi'

# %%
location = input('Enter your location here: ')
location = location.capitalize()

m = 'MuMbai'
m = m.capitalize()
if location == 'Delhi':
  print('Welcome to Delhi')
elif location == 'Chennai':
  print('Vanakam Chennai')
elif location == m :
  print('Aamchi Mumbai')
else:
  print('What is your location?')
# Out:
# Enter your location here: MuMBAi
# Aamchi Mumbai

# %%
'hello'.capitalize() == 'Hello'
# Out:
# True
