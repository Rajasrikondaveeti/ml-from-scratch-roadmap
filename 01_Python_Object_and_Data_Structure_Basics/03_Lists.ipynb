# %%
my_list = [1,2,3,4,5]

# %%
type(my_list)
# Out:
# list

# %%
my_list1 = ['A string',12,100.34,'g',['hi',123]]

# %%
type(my_list1)
# Out:
# list

# %%
len(my_list1)
# Out:
# 5

# %%
my_list1[0]
# Out:
# 'A string'

# %%
type(my_list1[0])
# Out:
# str

# %%
my_list1[-3]
# Out:
# 100.34

# %%
my_list1[2]
# Out:
# 100.34

# %%
my_list1[-1]
# Out:
# ['hi', 123]

# %%
my_list1[4]
# Out:
# ['hi', 123]

# %%
len(my_list1[-1])
# Out:
# 2

# %%
type(my_list1[-1])
# Out:
# list

# %%
my_list1[-1][0]
# Out:
# 'hi'

# %%
type(my_list1[-1][0])
# Out:
# str

# %%
my_list1[-1][0].upper()
# Out:
# 'HI'

# %%
my_list1[-1][0].capitalize()
# Out:
# 'Hi'

# %%
my_list1
# Out:
# ['A string', 12, 100.34, 'g', ['hi', 123]]

# %%
s = 'hello world'
s[:4]
# Out:
# 'hell'

# %%
my_list1[:3]
# Out:
# ['A string', 12, 100.34]

# %%
my_list1[1:4]
# Out:
# [12, 100.34, 'g']

# %%
len(my_list1[1:4])
# Out:
# 3

# %%
#concatenation
my_list1[1:4] + ['Shreyas',12.65,'World','Elon Musk']
# Out:
# [12, 100.34, 'g', 'Shreyas', 12.65, 'World', 'Elon Musk']

# %%
my_list1 + ['Hello','Shreyas']
# Out:
# ['A string', 12, 100.34, 'g', ['hi', 123], 'Hello', 'Shreyas']

# %%
my_list1 = my_list1 + ['Reassign to add new item permanently']

# %%
my_list1
# Out:
# ['A string',
#  12,
#  100.34,
#  'g',
#  ['hi', 123],
#  'Reassign to add new item permanently']

# %%
my_list1 * 2
# Out:
# ['A string',
#  12,
#  100.34,
#  'g',
#  ['hi', 123],
#  'Reassign to add new item permanently',
#  'A string',
#  12,
#  100.34,
#  'g',
#  ['hi', 123],
#  'Reassign to add new item permanently']

# %% [markdown]
# ## Basic List Methods

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
#append
my_list.append('new item')

# %%
my_list #adding item permanently
# Out:
# [1, 2, 3, 4, 5, 'new item']

# %%
v1 = my_list.append('another item')

# %%
v1

# %%
type(v1)
# Out:
# NoneType

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 'new item', 'another item']

# %%
#pop
my_list.pop()
# Out:
# 'another item'

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 'new item']

# %%
v2 = my_list.pop()

# %%
v2
# Out:
# 'new item'

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
l2 = [11,19,15,14,17]

# %%
l2
# Out:
# [11, 19, 15, 14, 17]

# %%
l2.pop(2)
# Out:
# 15

# %%
l2
# Out:
# [11, 19, 14, 17]

# %%
#Lists are mutable
l2[0] = 101

# %%
l2
# Out:
# [101, 19, 14, 17]

# %%
l2.reverse()

# %%
l2
# Out:
# [17, 14, 19, 101]

# %%
l2.sort()

# %%
l2
# Out:
# [14, 17, 19, 101]

# %%
alp = ['a','e','x','y','b','i','n']

# %%
alp.sort() #for descending use sort(reverse= True)

# %%
alp
# Out:
# ['a', 'b', 'e', 'i', 'n', 'x', 'y']

# %%
l5 = [3,4,5]
l5
# Out:
# [3, 4, 5]

# %%
#append
l5.append([6,7])

# %%
l5
# Out:
# [3, 4, 5, [6, 7]]

# %%
#extend
l5.extend([6,7])

# %%
l5
# Out:
# [3, 4, 5, [6, 7], 6, 7]

# %%
#index
l5.index([6, 7])
# Out:
# 3

# %%
#insert
l5.insert(2, ['inserted element','second element'])

# %%
l5
# Out:
# [3, 4, ['inserted element', 'second element'], 5, [6, 7], 6, 7]
