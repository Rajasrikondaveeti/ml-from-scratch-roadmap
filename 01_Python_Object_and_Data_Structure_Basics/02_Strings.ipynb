# %% [markdown]
# ## Creating a Striong

# %%
'hello'
# Out:
# 'hello'

# %%
'This is also a string'
# Out:
# 'This is also a string'

# %%
"String with double quotes"
# Out:
# 'String with double quotes'

# %%
'I'm going'
# Out:
#   File "<ipython-input-4-30ef0660fa5b>", line 1
#     'I'm going'
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm using double quotes here"
# Out:
# "I'm using double quotes here"

# %% [markdown]
# ## Printing a string

# %%
'Hello world 1'
'Hello world 2'
# Out:
# 'Hello world 2'

# %%
print('Hello world 1')
print('Hello world 2')
# Out:
# Hello world 1
# Hello world 2

# %%
print('Hello world 1\nHello world 2')
# Out:
# Hello world 1
# Hello world 2

# %%
s1 = 'Hello world 1'

# %%
type(s1)
# Out:
# str

# %%
s2 = print('Hello world 1')
# Out:
# Hello world 1

# %%
type(s2)
# Out:
# NoneType

# %% [markdown]
# # Strings Basics

# %%
len('hello world')
# Out:
# 11

# %%
len(s1)
# Out:
# 13

# %%
s = 'hello world'

# %%
len(s)
# Out:
# 11

# %%
s[-10]
# Out:
# 'e'

# %%
s[1]
# Out:
# 'e'

# %%
s[6]
# Out:
# 'w'

# %%
s[-5]
# Out:
# 'w'

# %% [markdown]
# ## Slicing

# %%
s
# Out:
# 'hello world'

# %%
s[:5]
# Out:
# 'hello'

# %%
s[-5:]
# Out:
# 'world'

# %%
s[-11:-6]
# Out:
# 'hello'

# %%
s[0:-6]
# Out:
# 'hello'

# %%
s[-11:5]
# Out:
# 'hello'

# %%
s[6:9]
# Out:
# 'wor'

# %%
s[-5:-2]
# Out:
# 'wor'

# %% [markdown]
# wor

# %%
s
# Out:
# 'hello world'

# %%
s[::2]
# Out:
# 'hlowrd'

# %%
s[::1]
# Out:
# 'hello world'

# %%
name = 'shreyas'

# %%
name[::-1]
# Out:
# 'sayerhs'

# %%
name[:-2]

#what happens to name[:-2:-1]
# Out:
# 'shrey'

# %% [markdown]
# ### String properties
#
# * strings are immutable

# %%
s
# Out:
# 'hello world'

# %%
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-fa085c53b004> in <cell line: 0>()
# ----> 1 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
l1 = [1,2,3]

# %%
type(l1)
# Out:
# list

# %%
l1[0] = 'Hi'

# %%
l1
# Out:
# ['Hi', 2, 3]

# %% [markdown]
# # Concatenate strings

# %%
name + ' shukla'
# Out:
# 'shreyas shukla'

# %%
z = 'hi' + ' masai'
z
# Out:
# 'hi masai'

# %%
2+3
# Out:
# 5

# %%
'2'+'3'
# Out:
# '23'

# %%
2 + '3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-8fd9dcfa4f42> in <cell line: 0>()
# ----> 1 2 + '3'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(2+3)
# Out:
# 5

# %%
print('2'+'3')
# Out:
# 23

# %%
s[:5] + z[-6:]
# Out:
# 'hello masai'

# %% [markdown]
# # Useful String Methods

# %%
s
# Out:
# 'hello world'

# %%
s.capitalize() #Capitalize first letter
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s1 = 'KJSKJAjguyfGJH'

# %%
s1.lower()
# Out:
# 'kjskjajguyfgjh'

# %%
s.count('l')
# Out:
# 3

# %%
s.count('o')
# Out:
# 2

# %%
s.find('w')
# Out:
# 6

# %%
s.split()
# Out:
# ['hello', 'world']

# %% [markdown]
# ##### is check methods

# %%
st = 'hello12345'

# %%
st.isalnum()
# Out:
# True

# %%
st.isalpha()
# Out:
# False

# %%
st.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.istitle()
# Out:
# False

# %%
a = 'Shreyas Shukla'
v = 'Virat kohli'

# %%
v.istitle()
# Out:
# False

# %%
a.istitle()
# Out:
# True

# %%
b = 'BALL'

# %%
b.isupper()
# Out:
# True

# %%
s1 = 'hello how are you'

# %%
s1.capitalize()
# Out:
# 'Hello how are you'

# %%
s1.title()
# Out:
# 'Hello How Are You'

# %%
s1.upper()
# Out:
# 'HELLO HOW ARE YOU'
