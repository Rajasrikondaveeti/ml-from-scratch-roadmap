# %% [markdown]
# # This is Heading
# ## This is Heading
# ### This is Heading
# #### This is Heading
# ##### This is Heading
# ###### This is Heading
#
# * This is a bullet point 1
# * This is bullet point 2

# %% [markdown]
# # Numbers
#
# ##### Basic Arithmetic

# %%
#Addition

2+1 #Anything after this hash is a comment. It will not be executed
# Out:
# 3

# %%
#Subtraction
7-3
# Out:
# 4

# %%
#Multiplication
4*3
# Out:
# 12

# %%
#Division
8/3
# Out:
# 2.6666666666666665

# %%
#Floor Division
19//3
# Out:
# 6

# %%
#Modulo
17%4
# Out:
# 1

# %%
#Power
2**3
# Out:
# 8

# %%
12**2
# Out:
# 144

# %%
#Order of Operations
12+10*10+3
# Out:
# 115

# %%
(12+10)*(10+3)
# Out:
# 286

# %% [markdown]
# # Variable Assignments

# %%
a = 5 #Creating Variable a

# %%
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b = 45/14

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 3.2142857142857144

# %%
a
# Out:
# 5

# %%
c = a + b

# %%
c
# Out:
# 8.214285714285715

# %%
type(c)
# Out:
# float

# %%
type(b)
# Out:
# float

# %%
a = a + a

# %%
a
# Out:
# 20

# %% [markdown]
# * A person's monthly income is 100Rs. He is paying 20% annual tax. How much annual tax does he pay. Use variable assignment wherever you can

# %%
income = 100
months = 12
annual_income = income * months
tax_rate = 0.2

annual_tax = annual_income * tax_rate

# %%
annual_tax
# Out:
# 240.0

# %% [markdown]
# ### Dynamic Typing

# %%
mydogs = 2

# %%
mydogs
# Out:
# 2

# %%
type(2)
# Out:
# int

# %%
mydogs = ['Jackie','Frankie']

# %%
mydogs
# Out:
# ['Jackie', 'Frankie']

# %%
type(mydogs)
# Out:
# list
