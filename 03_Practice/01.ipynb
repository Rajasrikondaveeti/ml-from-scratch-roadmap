# %%
new_lst = [12,
           ['32.87','name','by'],
           45.1,
           'Shreyas',
           ['Machine Learning', 'MASAI','IITG', 'course'],
           ['led'],
           [' '],
           'is']

# %% [markdown]
# Use indexing, slicing, concatenation and other techinques and tool to achieve following:
#
# * Course name is Machine Learning
# * Led by Shreyas
# * 87/12 + 45.1

# %%
new_lst[-2][-1]
# Out:
# ' '

# %%
#1
new_lst[4][-1].capitalize()+new_lst[-2][-1]+new_lst[1][1]+new_lst[-2][-1]+new_lst[-1]+new_lst[-2][-1]+new_lst[4][0]
# Out:
# 'Course name is Machine Learning'

# %%
# Out:
# 'Course name is'

# %%
#2
new_lst[-3][0].capitalize()+new_lst[-2][-1]+new_lst[1][-1]+new_lst[-2][-1]+new_lst[3]
# Out:
# 'Led by Shreyas'

# %%
#3
int(new_lst[1][0][-2:])/new_lst[0]+new_lst[2]
# Out:
# 52.35

# %%
new_list2 = [[98,
 [34.8,['hello world']],
  'Elon',
  [['Musk'],'Shreyas']],
 'controls',
 ' ',
 404,
 747]

# %%
new_list2
# Out:
# [[98, [34.8, ['hello world']], 'Elon', [['Musk'], 'Shreyas']],
#  'controls',
#  ' ',
#  404,
#  747]

# %% [markdown]
# * 'HELLO Elon Musk
# * Do a division of any two numbers from new_list2 and multiply it with addition of other two
# * replace 'Shreyas' with 'everyone'
# * 'Elon Musk controls everyone

# %%
new_list2[0]
# Out:
# [98, [34.8, ['hello world']], 'Elon', [['Musk'], 'Shreyas']]

# %%
new_list2[0][1][-1][0][:6].upper()+new_list2[0][-2]+new_list2[-3]+new_list2[0][-1][0][0]
# Out:
# 'HELLO Elon Musk'

# %%
(new_list2[0][0]/new_list2[0][1][0])*(new_list2[-1]+new_list2[-2])
# Out:
# 3241.32183908046

# %%
new_list2[0][-1][-1] = 'everyone'

# %%
new_list2
# Out:
# [[98, [34.8, ['hello world']], 'Elon', [['Musk'], 'everyone']],
#  'controls',
#  ' ',
#  404,
#  747]

# %%
new_list2[0][-2]+new_list2[-3]+new_list2[0][-1][0][0]+new_list2[-3]+new_list2[1]+new_list2[-3]+new_list2[0][-1][-1]
# Out:
# 'Elon Musk controls everyone'

# %%
new_list3 = [
    12.3,
    {'nested': [45.6, {'greeting':'hello at IIT Guwahati'}]},
    '45',
    98,
    {'org 1':'MASAI'},
    {'org 2': 'DAKSH gurukul'},
    {'person':'Steve Jobs'},
    'works',
    {'id': 302},
    'Google', ',',
    ' '
]

# %% [markdown]
# * 12.3+98+45
# * Steve Jobs works at Google
# * Replace 302 with your name
# * Shreyas(your name) at MASAI, DAKSH Gurukul, IIT Guwahati

# %%
#1
new_list3[0]+new_list3[3]+int(new_list3[2])
# Out:
# 155.3

# %%
# Out:
# ' '

# %%
#2
new_list3[6]['person']+new_list3[-1]+new_list3[7]+new_list3[-1]+new_list3[1]['nested'][1]['greeting'].split()[1]+' '+ new_list3[-3]
# Out:
# 'Steve Jobs works at Google'

# %%
#3
new_list3[-4]['id'] = 'Shreyas'

# %%
new_list3
# Out:
# [12.3,
#  {'nested': [45.6, {'greeting': 'hello at IIT Guwahati'}]},
#  '45',
#  98,
#  {'org 1': 'MASAI'},
#  {'org 2': 'DAKSH gurukul'},
#  {'person': 'Steve Jobs'},
#  'works',
#  {'id': 'Shreyas'},
#  'Google',
#  ',',
#  ' ']

# %%
# Out:
# 'IIT'

# %%
# Out:
# 'IIT Guwahati'

# %%
new_list3[-4]['id']+' '+new_list3[1]['nested'][1]['greeting'].split()[1]+ ' '+new_list3[4]['org 1']+', '+new_list3[5]['org 2']+', '+new_list3[1]['nested'][1]['greeting'].split()[-2]+ ' '+new_list3[1]['nested'][1]['greeting'].split()[-1]
# Out:
# 'Shreyas at MASAI, DAKSH gurukul, IIT Guwahati'
