# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
blobs = pd.read_csv('/content/drive/MyDrive/Daksh_Gururkul_IITG_May_2025/26_DBSCAN/Data/cluster_blobs.csv')
blobs.head()
# Out:
#          X1        X2
# 0  4.645333  6.822294
# 1  4.784032  6.422883
# 2 -5.851786  5.774331
# 3 -7.459592  6.456415
# 4  4.918911  6.961479

# %%
sns.scatterplot(data=blobs, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
moons = pd.read_csv('/content/drive/MyDrive/Daksh_Gururkul_IITG_May_2025/26_DBSCAN/Data/cluster_moons.csv')
moons.head()
# Out:
#          X1        X2
# 0  0.674362 -0.444625
# 1  1.547129 -0.239796
# 2  1.601930 -0.230792
# 3  0.014563  0.449752
# 4  1.503476 -0.389164

# %%
sns.scatterplot(data=moons, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
circles = pd.read_csv('/content/drive/MyDrive/Daksh_Gururkul_IITG_May_2025/26_DBSCAN/Data/cluster_circles.csv')
circles.head()
# Out:
#          X1        X2
# 0 -0.348677  0.010157
# 1 -0.176587 -0.954283
# 2  0.301703 -0.113045
# 3 -0.782889 -0.719468
# 4 -0.733280 -0.757354

# %%
sns.scatterplot(data=circles, x='X1',y='X2')
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %% [markdown]
# # Finding Labels

# %%
def display_categories(model,data):
  labels = model.fit_predict(data)
  sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')

# %% [markdown]
# # KMeans Results

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=2)

# %%
display_categories(model=model, data=moons)

# %%
display_categories(model=model, data=circles)

# %%
model = KMeans(n_clusters=3)
display_categories(model=model, data=blobs)

# %% [markdown]
# # DBSCAN results

# %%
from sklearn.cluster import DBSCAN

# %%
model = DBSCAN(eps=0.6)

# %%
display_categories(model=model,data=blobs)

# %%
model = DBSCAN(eps=0.2)
display_categories(model=model,data=moons)

# %%
model = DBSCAN(eps=0.2)
display_categories(model=model,data=circles)
